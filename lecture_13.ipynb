# %% [markdown]
# lecture 13 irfan malik codding

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Titanic.csv')

# %%
df.head(5)
# Out:
#    PassengerId  Pclass             Name     Sex  Age  SibSp  Parch  \
# 0            1       3     Allison Hill    male   17      4      2
# 1            2       1      Noah Rhodes    male   60      2      2
# 2            3       3  Angie Henderson    male   64      0      0
# 3            4       3    Daniel Wagner    male   35      4      0
# 4            5       1  Cristian Santos  female   70      0      3
#
#                                  Ticket    Fare Embarked  Survived
# 0  43d75413-a939-4bd1-a516-b0d47d3572cc  144.08        Q         1
# 1  6334fa2a-8b4b-47e7-a451-5ae01754bf08  249.04        S         0
# 2  61a66444-e2af-4629-9efb-336e2f546033   50.31        Q         1
# 3  0b6c03c8-721e-4419-afc3-e6495e911b91  235.20        C         1
# 4  436e3c49-770e-49db-b092-d40143675d58  160.17        C         1

# %%
df.tail(5)
# Out:
#      PassengerId  Pclass               Name     Sex  Age  SibSp  Parch  \
# 995          996       2      Brittany Ward    male   69      2      3
# 996          997       2     Edward Stanley  female   61      4      4
# 997          998       3  Christina Johnson    male   10      4      1
# 998          999       3       Edgar Miller    male   50      3      2
# 999         1000       1  Elizabeth Sanders    male    3      3      3
#
#                                    Ticket    Fare Embarked  Survived
# 995  75eb0e8f-a090-460d-a7c7-655a7b434a72   19.87        Q         1
# 996  e55b93ad-8976-4471-9d7f-57d1e45def26   85.35        C         0
# 997  d06d3943-c8b3-415e-b664-704355c9bf0f  444.22        C         0
# 998  0e5779ec-be1a-470f-ad83-a4c869f8d3e4  234.67        S         1
# 999  90a014ab-4ca1-4abd-8565-0e0bd5c97d5d  286.65        C         1

# %%
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age              int64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# Survived         int64
# dtype: object

# %%
df.drop(['Name'], axis=1 , inplace = True)
df.head()
# Out:
#    PassengerId  Pclass     Sex  Age  SibSp  Parch  \
# 0            1       3    male   17      4      2
# 1            2       1    male   60      2      2
# 2            3       3    male   64      0      0
# 3            4       3    male   35      4      0
# 4            5       1  female   70      0      3
#
#                                  Ticket    Fare Embarked  Survived
# 0  43d75413-a939-4bd1-a516-b0d47d3572cc  144.08        Q         1
# 1  6334fa2a-8b4b-47e7-a451-5ae01754bf08  249.04        S         0
# 2  61a66444-e2af-4629-9efb-336e2f546033   50.31        Q         1
# 3  0b6c03c8-721e-4419-afc3-e6495e911b91  235.20        C         1
# 4  436e3c49-770e-49db-b092-d40143675d58  160.17        C         1

# %%
df.rename(columns = {'Sex':'gender', 'Age':'ages'} , inplace  = True)
df.head(5)
# Out:
#    PassengerId  Pclass  gender  ages  SibSp  Parch  \
# 0            1       3    male    17      4      2
# 1            2       1    male    60      2      2
# 2            3       3    male    64      0      0
# 3            4       3    male    35      4      0
# 4            5       1  female    70      0      3
#
#                                  Ticket    Fare Embarked  Survived
# 0  43d75413-a939-4bd1-a516-b0d47d3572cc  144.08        Q         1
# 1  6334fa2a-8b4b-47e7-a451-5ae01754bf08  249.04        S         0
# 2  61a66444-e2af-4629-9efb-336e2f546033   50.31        Q         1
# 3  0b6c03c8-721e-4419-afc3-e6495e911b91  235.20        C         1
# 4  436e3c49-770e-49db-b092-d40143675d58  160.17        C         1

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows:", duplicate_rows_df.shape)
# Out:
# number of duplicate rows: (0, 10)

# %%
df.count()
# Out:
# PassengerId    1000
# Pclass         1000
# gender         1000
# ages           1000
# SibSp          1000
# Parch          1000
# Ticket         1000
# Fare           1000
# Embarked       1000
# Survived       1000
# dtype: int64

# %%
# drop duplicates rows
df_var = df.drop_duplicates()
df.head()
# Out:
#    PassengerId  Pclass  gender  ages  SibSp  Parch  \
# 0            1       3    male    17      4      2
# 1            2       1    male    60      2      2
# 2            3       3    male    64      0      0
# 3            4       3    male    35      4      0
# 4            5       1  female    70      0      3
#
#                                  Ticket    Fare Embarked  Survived
# 0  43d75413-a939-4bd1-a516-b0d47d3572cc  144.08        Q         1
# 1  6334fa2a-8b4b-47e7-a451-5ae01754bf08  249.04        S         0
# 2  61a66444-e2af-4629-9efb-336e2f546033   50.31        Q         1
# 3  0b6c03c8-721e-4419-afc3-e6495e911b91  235.20        C         1
# 4  436e3c49-770e-49db-b092-d40143675d58  160.17        C         1

# %%
print(df.isnull().sum())
# Out:
# PassengerId    0
# Pclass         0
# gender         0
# ages           0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Survived       0
# dtype: int64

# %%
df.dropna(inplace=True)
df.head()
df.count()
# Out:
# PassengerId    1000
# Pclass         1000
# gender         1000
# ages           1000
# SibSp          1000
# Parch          1000
# Ticket         1000
# Fare           1000
# Embarked       1000
# Survived       1000
# dtype: int64

# %%
# detecting outliers using box plot as
sns.boxplot(x = df['Fare'], hue = df['Survived'])
plt.show()

# %%
q1 = df.select_dtypes(include=["number"]).quantile(0.25)
q3 = df.select_dtypes(include=["number"]).quantile(0.75)
iqr = q3 - q1
print(iqr)
# Out:
# PassengerId    499.5000
# Pclass           2.0000
# ages            40.0000
# SibSp            2.0000
# Parch            2.0000
# Fare           239.3675
# Survived         1.0000
# dtype: float64

# %%
df.select_dtypes(include=["number"]).corr()
# Out:
#              PassengerId    Pclass      ages     SibSp     Parch      Fare  \
# PassengerId     1.000000 -0.028581 -0.060180  0.005650  0.051432 -0.014822
# Pclass         -0.028581  1.000000 -0.004145  0.000987 -0.005899  0.050952
# ages           -0.060180 -0.004145  1.000000  0.016709 -0.039179 -0.033666
# SibSp           0.005650  0.000987  0.016709  1.000000  0.013374  0.037322
# Parch           0.051432 -0.005899 -0.039179  0.013374  1.000000 -0.016533
# Fare           -0.014822  0.050952 -0.033666  0.037322 -0.016533  1.000000
# Survived       -0.008592  0.023685 -0.022637  0.034079 -0.063090 -0.018823
#
#              Survived
# PassengerId -0.008592
# Pclass       0.023685
# ages        -0.022637
# SibSp        0.034079
# Parch       -0.063090
# Fare        -0.018823
# Survived     1.000000

# %%
sns.heatmap(df.select_dtypes(include=["number"]).corr(), cmap= 'Accent' , annot = True)
plt.show()
